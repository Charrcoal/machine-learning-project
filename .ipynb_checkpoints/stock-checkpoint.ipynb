# %% [markdown]
# # Apple

# %%
import yfinance as yf

# %%
apple_ticker = yf.Ticker("AAPL")
# get stock info
# get historical market data
apple_df= apple_ticker.history(period="6y")
apple_df["Change"] = (apple_df["Close"] - apple_df["Open"]).map("{:.2f}".format)
apple_df["%Change"] = ((apple_df["Close"] - apple_df["Open"])/apple_df["Open"]*100).map("{:.2f}%".format)

apple_df
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits  \
# Date
# 2014-07-18   84.79   85.81   84.25   85.53  49988000        0.0             0
# 2014-07-21   86.03   86.04   84.88   85.08  39079000        0.0             0
# 2014-07-22   85.75   85.94   85.25   85.79  55197000        0.0             0
# 2014-07-23   86.42   88.65   86.20   88.03  92918000        0.0             0
# 2014-07-24   87.89   88.14   87.33   87.88  45729000        0.0             0
# ...            ...     ...     ...     ...       ...        ...           ...
# 2020-07-13  389.06  399.82  381.03  381.91  47912300        0.0             0
# 2020-07-14  379.36  389.02  375.51  388.23  42747300        0.0             0
# 2020-07-15  395.96  396.99  385.96  390.90  38299500        0.0             0
# 2020-07-16  386.25  389.62  383.62  386.09  27644400        0.0             0
# 2020-07-17  387.95  388.59  383.36  385.31  23001300        0.0             0
#
#            Change %Change
# Date
# 2014-07-18   0.74   0.87%
# 2014-07-21  -0.95  -1.10%
# 2014-07-22   0.04   0.05%
# 2014-07-23   1.61   1.86%
# 2014-07-24  -0.01  -0.01%
# ...           ...     ...
# 2020-07-13  -7.15  -1.84%
# 2020-07-14   8.87   2.34%
# 2020-07-15  -5.06  -1.28%
# 2020-07-16  -0.16  -0.04%
# 2020-07-17  -2.64  -0.68%
#
# [1511 rows x 9 columns]

# %%
# find the change of stocks each day
apple_df.loc[apple_df['Open']> apple_df['Close'], 'Result'] = 0
apple_df.loc[apple_df['Open']< apple_df['Close'], 'Result'] = 1
apple_df
apple_df.to_csv("apple_stock.csv")

# %%
import matplotlib.pyplot as plt
import numpy as np
x_axis = np.arange(len(apple_df))
plt.plot(x_axis,apple_df["Close"])
plt.plot(x_axis,apple_df["Open"])

# %% [markdown]
# # Facebook

# %%
facebook_ticker = yf.Ticker("FB")
# get stock info
# get historical market data
facebook_df= facebook_ticker.history(period="6y")
facebook_df["Change"] = (facebook_df["Close"] - facebook_df["Open"]).map("{:.2f}".format)
facebook_df["%Change"] = ((facebook_df["Close"] - facebook_df["Open"])/facebook_df["Open"]*100).map("{:.2f}%".format)
facebook_df
# Out:
#               Open    High     Low   Close     Volume  Dividends  \
# Date
# 2014-07-18   66.80   68.46   66.16   68.42   42456000          0
# 2014-07-21   68.81   69.96   68.50   69.40   49539000          0
# 2014-07-22   69.76   69.77   68.61   69.27   40398000          0
# 2014-07-23   69.74   71.33   69.61   71.29   78435000          0
# 2014-07-24   75.96   76.74   74.51   74.98  124168000          0
# ...            ...     ...     ...     ...        ...        ...
# 2020-07-13  247.01  250.15  238.42  239.00   24674900          0
# 2020-07-14  236.76  240.33  232.03  239.73   23378100          0
# 2020-07-15  241.55  244.82  238.05  240.28   19133600          0
# 2020-07-16  238.00  241.76  236.33  240.93   18880700          0
# 2020-07-17  241.00  244.16  237.86  242.03   18144100          0
#
#             Stock Splits Change %Change
# Date
# 2014-07-18             0   1.62   2.43%
# 2014-07-21             0   0.59   0.86%
# 2014-07-22             0  -0.49  -0.70%
# 2014-07-23             0   1.55   2.22%
# 2014-07-24             0  -0.98  -1.29%
# ...                  ...    ...     ...
# 2020-07-13             0  -8.01  -3.24%
# 2020-07-14             0   2.97   1.25%
# 2020-07-15             0  -1.27  -0.53%
# 2020-07-16             0   2.93   1.23%
# 2020-07-17             0   1.03   0.43%
#
# [1511 rows x 9 columns]

# %%
# find the change of stocks each day
facebook_df.loc[facebook_df['Open']> facebook_df['Close'], 'Result'] = 0
facebook_df.loc[facebook_df['Open']< facebook_df['Close'], 'Result'] = 1
facebook_df
facebook.to_csv("facebook_stock.csv")
# Out:
#               Open    High     Low   Close     Volume  Dividends  \
# Date
# 2014-07-18   66.80   68.46   66.16   68.42   42456000          0
# 2014-07-21   68.81   69.96   68.50   69.40   49539000          0
# 2014-07-22   69.76   69.77   68.61   69.27   40398000          0
# 2014-07-23   69.74   71.33   69.61   71.29   78435000          0
# 2014-07-24   75.96   76.74   74.51   74.98  124168000          0
# ...            ...     ...     ...     ...        ...        ...
# 2020-07-13  247.01  250.15  238.42  239.00   24674900          0
# 2020-07-14  236.76  240.33  232.03  239.73   23378100          0
# 2020-07-15  241.55  244.82  238.05  240.28   19133600          0
# 2020-07-16  238.00  241.76  236.33  240.93   18880700          0
# 2020-07-17  241.00  244.16  237.86  242.03   18144100          0
#
#             Stock Splits Change %Change  Result
# Date
# 2014-07-18             0   1.62   2.43%     1.0
# 2014-07-21             0   0.59   0.86%     1.0
# 2014-07-22             0  -0.49  -0.70%     0.0
# 2014-07-23             0   1.55   2.22%     1.0
# 2014-07-24             0  -0.98  -1.29%     0.0
# ...                  ...    ...     ...     ...
# 2020-07-13             0  -8.01  -3.24%     0.0
# 2020-07-14             0   2.97   1.25%     1.0
# 2020-07-15             0  -1.27  -0.53%     0.0
# 2020-07-16             0   2.93   1.23%     1.0
# 2020-07-17             0   1.03   0.43%     1.0
#
# [1511 rows x 10 columns]

# %%
x_axis = np.arange(len(facebook_df))
plt.plot(x_axis,facebook_df["Close"])
plt.plot(x_axis,facebook_df["Open"])

# %% [markdown]
# # Google

# %%
google_ticker = yf.Ticker("GOOGL")
# get stock info
# get historical market data
google_df= google_ticker.history(period="6y")
google_df["Change"] = (google_df["Close"] - google_df["Open"]).map("{:.2f}".format)
google_df["%Change"] = ((google_df["Close"] - google_df["Open"])/google_df["Open"]*100).map("{:.2f}%".format)
google_df
# Out:
#                Open     High      Low    Close   Volume  Dividends  \
# Date
# 2014-07-18   603.01   606.70   590.92   605.11  4871600          0
# 2014-07-21   601.35   604.16   594.45   598.44  2237900          0
# 2014-07-22   599.70   608.89   599.26   603.57  1881600          0
# 2014-07-23   602.05   607.05   601.35   605.19  1106000          0
# 2014-07-24   605.53   608.91   601.00   603.01  1355000          0
# ...             ...      ...      ...      ...      ...        ...
# 2020-07-13  1549.94  1576.36  1506.56  1512.23  2147700          0
# 2020-07-14  1492.79  1522.80  1485.93  1520.86  1905400          0
# 2020-07-15  1523.23  1536.33  1497.83  1516.88  1551300          0
# 2020-07-16  1501.50  1515.91  1488.27  1514.92  1324200          0
# 2020-07-17  1516.91  1523.43  1498.10  1516.85  1712300          0
#
#             Stock Splits  Change %Change
# Date
# 2014-07-18             0    2.10   0.35%
# 2014-07-21             0   -2.91  -0.48%
# 2014-07-22             0    3.87   0.65%
# 2014-07-23             0    3.14   0.52%
# 2014-07-24             0   -2.52  -0.42%
# ...                  ...     ...     ...
# 2020-07-13             0  -37.71  -2.43%
# 2020-07-14             0   28.07   1.88%
# 2020-07-15             0   -6.35  -0.42%
# 2020-07-16             0   13.42   0.89%
# 2020-07-17             0   -0.06  -0.00%
#
# [1511 rows x 9 columns]

# %%
# find the change of stocks each day
google_df.loc[google_df['Open']> google_df['Close'], 'Result'] = 0
google_df.loc[google_df['Open']< google_df['Close'], 'Result'] = 1
google_df
google_df.to_csv("google_stock.csv")

# %%
x_axis = np.arange(len(google_df))
plt.plot(x_axis,google_df["Close"])
plt.plot(x_axis,google_df["Open"])

# %% [markdown]
# # Amazon

# %%
amazon_ticker = yf.Ticker("AMZN")
# get stock info
# get historical market data
amazon_df= amazon_ticker.history(period="6y")
amazon_df["Change"] = (amazon_df["Close"] - amazon_df["Open"]).map("{:.2f}".format)
amazon_df["%Change"] = ((amazon_df["Close"] - amazon_df["Open"])/amazon_df["Open"]*100).map("{:.2f}%".format)
amazon_df
# Out:
#                Open     High      Low    Close   Volume  Dividends  \
# Date
# 2014-07-18   354.40   359.68   352.08   358.66  3407400          0
# 2014-07-21   358.10   361.71   356.72   359.76  2278400          0
# 2014-07-22   355.25   362.93   355.25   360.84  2888900          0
# 2014-07-23   359.05   360.63   356.62   358.14  2687300          0
# 2014-07-24   359.98   364.85   358.52   358.61  7088700          0
# ...             ...      ...      ...      ...      ...        ...
# 2020-07-13  3251.06  3344.29  3068.39  3104.00  7720400          0
# 2020-07-14  3089.00  3127.38  2950.00  3084.00  7231900          0
# 2020-07-15  3080.23  3098.35  2973.18  3008.87  5788900          0
# 2020-07-16  2971.06  3032.00  2918.23  2999.90  6394200          0
# 2020-07-17  3009.00  3024.00  2948.45  2961.97  4739500          0
#
#             Stock Splits   Change %Change
# Date
# 2014-07-18             0     4.26   1.20%
# 2014-07-21             0     1.66   0.46%
# 2014-07-22             0     5.59   1.57%
# 2014-07-23             0    -0.91  -0.25%
# 2014-07-24             0    -1.37  -0.38%
# ...                  ...      ...     ...
# 2020-07-13             0  -147.06  -4.52%
# 2020-07-14             0    -5.00  -0.16%
# 2020-07-15             0   -71.36  -2.32%
# 2020-07-16             0    28.84   0.97%
# 2020-07-17             0   -47.03  -1.56%
#
# [1511 rows x 9 columns]

# %%
# find the change of stocks each day
amazon_df.loc[amazon_df['Open']> amazon_df['Close'], 'Result'] = 0
amazon_df.loc[amazon_df['Open']< amazon_df['Close'], 'Result'] = 1
amazon_df
amazon_df.to_csv("amazon_stock.csv")
# Out:
#                Open     High      Low    Close   Volume  Dividends  \
# Date
# 2014-07-18   354.40   359.68   352.08   358.66  3407400          0
# 2014-07-21   358.10   361.71   356.72   359.76  2278400          0
# 2014-07-22   355.25   362.93   355.25   360.84  2888900          0
# 2014-07-23   359.05   360.63   356.62   358.14  2687300          0
# 2014-07-24   359.98   364.85   358.52   358.61  7088700          0
# ...             ...      ...      ...      ...      ...        ...
# 2020-07-13  3251.06  3344.29  3068.39  3104.00  7720400          0
# 2020-07-14  3089.00  3127.38  2950.00  3084.00  7231900          0
# 2020-07-15  3080.23  3098.35  2973.18  3008.87  5788900          0
# 2020-07-16  2971.06  3032.00  2918.23  2999.90  6394200          0
# 2020-07-17  3009.00  3024.00  2948.45  2961.97  4739500          0
#
#             Stock Splits   Change %Change  Result
# Date
# 2014-07-18             0     4.26   1.20%     1.0
# 2014-07-21             0     1.66   0.46%     1.0
# 2014-07-22             0     5.59   1.57%     1.0
# 2014-07-23             0    -0.91  -0.25%     0.0
# 2014-07-24             0    -1.37  -0.38%     0.0
# ...                  ...      ...     ...     ...
# 2020-07-13             0  -147.06  -4.52%     0.0
# 2020-07-14             0    -5.00  -0.16%     0.0
# 2020-07-15             0   -71.36  -2.32%     0.0
# 2020-07-16             0    28.84   0.97%     1.0
# 2020-07-17             0   -47.03  -1.56%     0.0
#
# [1511 rows x 10 columns]

# %%
x_axis = np.arange(len(amazon_df))
plt.plot(x_axis,amazon_df["Close"])
plt.plot(x_axis,amazon_df["Open"])

# %% [markdown]
# # Samsung

# %%
samsung_ticker = yf.Ticker("SSNLF")
# get stock info
# get historical market data
samsung_df= samsung_ticker.history(period="6y")
samsung_df["Change"] = (samsung_df["Close"] - samsung_df["Open"]).map("{:.2f}".format)
samsung_df["%Change"] = ((samsung_df["Close"] - samsung_df["Open"])/samsung_df["Open"]*100).map("{:.2f}%".format)
samsung_df
# Out:
#             Open  High   Low  Close  Volume  Dividends  Stock Splits Change  \
# Date
# 2014-07-18  28.0  28.0  28.0   28.0       0          0             0   0.00
# 2014-07-21  28.0  28.0  28.0   28.0       0          0             0   0.00
# 2014-07-22  28.0  28.0  28.0   28.0       0          0             0   0.00
# 2014-07-23  26.4  26.4  26.4   26.4     250          0             0   0.00
# 2014-07-24  26.4  26.4  26.4   26.4       0          0             0   0.00
# ...          ...   ...   ...    ...     ...        ...           ...    ...
# 2020-07-10  44.2  44.2  44.2   44.2       0          0             0   0.00
# 2020-07-13  44.2  44.2  44.2   44.2       0          0             0   0.00
# 2020-07-14  44.2  44.2  44.2   44.2       0          0             0   0.00
# 2020-07-15  44.2  44.2  44.2   44.2       0          0             0   0.00
# 2020-07-16  44.2  44.2  44.2   44.2       0          0             0   0.00
#
#            %Change
# Date
# 2014-07-18   0.00%
# 2014-07-21   0.00%
# 2014-07-22   0.00%
# 2014-07-23   0.00%
# 2014-07-24   0.00%
# ...            ...
# 2020-07-10   0.00%
# 2020-07-13   0.00%
# 2020-07-14   0.00%
# 2020-07-15   0.00%
# 2020-07-16   0.00%
#
# [1510 rows x 9 columns]

# %%
# find the change of stocks each day
samsung_df.loc[samsung_df['Open']> samsung_df['Close'], 'Result'] = 0
samsung_df.loc[samsung_df['Open']< samsung_df['Close'], 'Result'] = 1
samsung_df
samsung_df.to_csv("samsung_stock.csv")
# Out:
#             Open  High   Low  Close  Volume  Dividends  Stock Splits Change  \
# Date
# 2014-07-18  28.0  28.0  28.0   28.0       0          0             0   0.00
# 2014-07-21  28.0  28.0  28.0   28.0       0          0             0   0.00
# 2014-07-22  28.0  28.0  28.0   28.0       0          0             0   0.00
# 2014-07-23  26.4  26.4  26.4   26.4     250          0             0   0.00
# 2014-07-24  26.4  26.4  26.4   26.4       0          0             0   0.00
# ...          ...   ...   ...    ...     ...        ...           ...    ...
# 2020-07-10  44.2  44.2  44.2   44.2       0          0             0   0.00
# 2020-07-13  44.2  44.2  44.2   44.2       0          0             0   0.00
# 2020-07-14  44.2  44.2  44.2   44.2       0          0             0   0.00
# 2020-07-15  44.2  44.2  44.2   44.2       0          0             0   0.00
# 2020-07-16  44.2  44.2  44.2   44.2       0          0             0   0.00
#
#            %Change  Result
# Date
# 2014-07-18   0.00%     NaN
# 2014-07-21   0.00%     NaN
# 2014-07-22   0.00%     NaN
# 2014-07-23   0.00%     NaN
# 2014-07-24   0.00%     NaN
# ...            ...     ...
# 2020-07-10   0.00%     NaN
# 2020-07-13   0.00%     NaN
# 2020-07-14   0.00%     NaN
# 2020-07-15   0.00%     NaN
# 2020-07-16   0.00%     NaN
#
# [1510 rows x 10 columns]

# %%
x_axis = np.arange(len(samsung_df))
plt.plot(x_axis,samsung_df["Close"])
plt.plot(x_axis,samsung_df["Open"])

# %% [markdown]
# # Blackberry

# %%
blackberry_ticker = yf.Ticker("BB")
# get stock info
# get historical market data
blackberry_df= blackberry_ticker.history(period="6y")
blackberry_df["Change"] = (blackberry_df["Close"] - blackberry_df["Open"]).map("{:.2f}".format)
blackberry_df["%Change"] = ((blackberry_df["Close"] - blackberry_df["Open"])/blackberry_df["Open"]*100).map("{:.2f}%".format)
blackberry_df
# Out:
#              Open   High   Low  Close    Volume  Dividends  Stock Splits  \
# Date
# 2014-07-18   9.89  10.13  9.89  10.04  15126900          0             0
# 2014-07-21  10.13  10.29  9.91  10.00  10912200          0             0
# 2014-07-22  10.08  10.10  9.89   9.92   7789800          0             0
# 2014-07-23   9.95  10.03  9.75   9.83  10581600          0             0
# 2014-07-24   9.78  10.44  9.70  10.38  31239400          0             0
# ...           ...    ...   ...    ...       ...        ...           ...
# 2020-07-13   4.75   4.79  4.56   4.58   3526900          0             0
# 2020-07-14   4.55   4.61  4.45   4.58   3662800          0             0
# 2020-07-15   4.65   4.73  4.61   4.71   3575500          0             0
# 2020-07-16   4.65   4.68  4.57   4.65   2076300          0             0
# 2020-07-17   4.63   4.85  4.63   4.80   2771600          0             0
#
#            Change %Change
# Date
# 2014-07-18   0.15   1.52%
# 2014-07-21  -0.13  -1.28%
# 2014-07-22  -0.16  -1.59%
# 2014-07-23  -0.12  -1.21%
# 2014-07-24   0.60   6.13%
# ...           ...     ...
# 2020-07-13  -0.17  -3.58%
# 2020-07-14   0.03   0.66%
# 2020-07-15   0.06   1.29%
# 2020-07-16   0.00   0.00%
# 2020-07-17   0.17   3.67%
#
# [1511 rows x 9 columns]

# %%
# find the change of stocks each day
blackberry_df.loc[blackberry_df['Open']> blackberry_df['Close'], 'Result'] = 0
blackberry_df.loc[blackberry_df['Open']< blackberry_df['Close'], 'Result'] = 1
blackberry_df
blackberry.to_csv("blackberry_stock.csv")
# Out:
#              Open   High   Low  Close    Volume  Dividends  Stock Splits  \
# Date
# 2014-07-18   9.89  10.13  9.89  10.04  15126900          0             0
# 2014-07-21  10.13  10.29  9.91  10.00  10912200          0             0
# 2014-07-22  10.08  10.10  9.89   9.92   7789800          0             0
# 2014-07-23   9.95  10.03  9.75   9.83  10581600          0             0
# 2014-07-24   9.78  10.44  9.70  10.38  31239400          0             0
# ...           ...    ...   ...    ...       ...        ...           ...
# 2020-07-13   4.75   4.79  4.56   4.58   3526900          0             0
# 2020-07-14   4.55   4.61  4.45   4.58   3662800          0             0
# 2020-07-15   4.65   4.73  4.61   4.71   3575500          0             0
# 2020-07-16   4.65   4.68  4.57   4.65   2076300          0             0
# 2020-07-17   4.63   4.85  4.63   4.80   2771600          0             0
#
#            Change %Change  Result
# Date
# 2014-07-18   0.15   1.52%     1.0
# 2014-07-21  -0.13  -1.28%     0.0
# 2014-07-22  -0.16  -1.59%     0.0
# 2014-07-23  -0.12  -1.21%     0.0
# 2014-07-24   0.60   6.13%     1.0
# ...           ...     ...     ...
# 2020-07-13  -0.17  -3.58%     0.0
# 2020-07-14   0.03   0.66%     1.0
# 2020-07-15   0.06   1.29%     1.0
# 2020-07-16   0.00   0.00%     NaN
# 2020-07-17   0.17   3.67%     1.0
#
# [1511 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
x_axis = np.arange(len(blackberry_df))
plt.plot(x_axis,blackberry_df["Open"])
plt.plot(x_axis,blackberry_df["Close"])
